# %% [markdown]
# <a href="https://colab.research.google.com/github/aadi3030/yolov5/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="tvBAyMfGm4WUjowEnpLs")  # ← use your private API key
project = rf.workspace("aaditya-hecng").project("bio-medical-waste-zx4ei")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 16.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 53.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 81.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to BIO-MEDICAL-WASTE--1 in yolov8:: 100%|██████████| 80/80 [00:00<00:00, 7527.97it/s]

# %%
# !ls
# Out:
# BIO-MEDICAL-WASTE--1  sample_data

# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 45.8 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
model.train(data="/content/Bio-Medical-Waste-1/data.yaml", epochs=50, imgsz=640)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.225 🚀 Python-3.12.12 torch-2.8.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
# !ls /content
# Out:
# BIO-MEDICAL-WASTE--1  runs  sample_data  yolov8n.pt

# %%
# !ls /content/BIO-MEDICAL-WASTE--1
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  train

# %%
# Install Ultralytics (YOLOv8)
# !pip install ultralytics

# Import YOLO
from ultralytics import YOLO

# Load a pre-trained YOLOv8 model (nano version, small & fast)
model = YOLO("yolov8n.pt")

# Train your biomedical waste dataset
model.train(
    data="/content/BIO-MEDICAL-WASTE--1/data.yaml",  # ✅ correct dataset path
    epochs=50,     # number of training cycles
    imgsz=640,     # image size
    batch=16,      # you can reduce this if RAM is low
    name="biomedical_yolo_train"  # training folder name inside runs/detect/
)
# Out:
# ...
# Ultralytics 8.3.225 🚀 Python-3.12.12 torch-2.8.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
# !ls /content/datasets
# Out:
# ls: cannot access '/content/datasets': No such file or directory

# %%
# !pip install roboflow ultralytics

from roboflow import Roboflow
rf = Roboflow(api_key="tvBAyMfGm4WUjowEnpLs")  # 🔑 put your private API key here
project = rf.workspace("aaditya-hecng").project("bio-medical-waste-zx4ei")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#   Using cached roboflow-1.2.11-py3-none-any.whl.metadata (9.7 kB)
# ...
#   Using cached ultralytics-8.3.225-py3-none-any.whl.metadata (37 kB)
# ...
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# ...
#   Using cached opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# ...
#   Using cached ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# ...
# Using cached roboflow-1.2.11-py3-none-any.whl (89 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
# Using cached ultralytics-8.3.225-py3-none-any.whl (1.1 MB)
# Using cached ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
# ...

# %%
# !ls /content
# Out:
# BIO-MEDICAL-WASTE--1  sample_data

# %%
# !ls /content/BIO-MEDICAL-WASTE--1
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  train

# %%
# !cp -r /content/BIO-MEDICAL-WASTE--1/train /content/BIO-MEDICAL-WASTE--1/valid

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/BIO-MEDICAL-WASTE--1/data.yaml",  # your correct dataset path
    epochs=50,
    imgsz=640,
    batch=16,
    name="biomedical_yolo_train"
)
# Out:
# ...
# Ultralytics 8.3.225 🚀 Python-3.12.12 torch-2.8.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
from ultralytics import YOLO

# Load your trained model
model = YOLO("/content/runs/detect/biomedical_yolo_train/weights/best.pt")

# %%
results = model.predict(source="syringe.png", show=True)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3985391252.py in <cell line: 0>()
# ----> 1 results = model.predict(source="syringe.png", show=True)
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
#     538         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     539             self.predictor.set_prompts(prompts)
# --> 540         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     541
#     542     def track(
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/predictor.py in __call__(self, source, model, stream, *args, **kwargs)
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-11fe4e78-7e95-40a8-bf66-13058ebcd398" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-11fe4e78-7e95-40a8-bf66-13058ebcd398">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
results = model.predict(source="syringe.png", show=True, conf=0.5)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipython-input-3929884282.py in <cell line: 0>()
# ----> 1 results = model.predict(source="syringe.png", show=True, conf=0.5)
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
#     538         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     539             self.predictor.set_prompts(prompts)
# --> 540         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     541
#     542     def track(
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/predictor.py in __call__(self, source, model, stream, *args, **kwargs)
#     223             return self.stream_inference(source, model, *args, **kwargs)
#     224         else:
# ...

# %%
# ✅ Prediction without window popups (safe in Colab)
from matplotlib import pyplot as plt
import cv2

results = model.predict(source="/content/syringe.png", conf=0.5, show=False)

# Plot results inline
result_image = results[0].plot()
plt.imshow(cv2.cvtColor(result_image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
# Out:
# image 1/1 /content/syringe.png: 352x640 (no detections), 135.1ms
# Speed: 4.2ms preprocess, 135.1ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a31e87cc-bf77-4df2-a200-3c69f67ea171" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a31e87cc-bf77-4df2-a200-3c69f67ea171">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-756996ce-f014-4f6e-9edd-9b2ba79d5341" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-756996ce-f014-4f6e-9edd-9b2ba79d5341">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# ✅ Prediction without window popups (safe in Colab)
from matplotlib import pyplot as plt
import cv2

results = model.predict(source="/content/gloves.jpg", conf=0.2, show=False)

# Plot results inline
result_image = results[0].plot()
plt.imshow(cv2.cvtColor(result_image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
# Out:
# image 1/1 /content/gloves.jpg: 448x640 1 GLOVES, 210.1ms
# Speed: 5.6ms preprocess, 210.1ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)

# %%
# ✅ Prediction without window popups (safe in Colab)
from matplotlib import pyplot as plt
import cv2

results = model.predict(source="/content/biomedical.jpg", conf=0.2, show=False)

# Plot results inline
result_image = results[0].plot()
plt.imshow(cv2.cvtColor(result_image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
# Out:
# image 1/1 /content/biomedical.jpg: 320x640 1 SYRINGES, 178.7ms
# Speed: 4.4ms preprocess, 178.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)

# %%
# ✅ Prediction without window popups (safe in Colab)
from matplotlib import pyplot as plt
import cv2

results = model.predict(source="/content/syringe.png", conf=0.2, show=False)

# Plot results inline
result_image = results[0].plot()
plt.imshow(cv2.cvtColor(result_image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
# Out:
# image 1/1 /content/syringe.png: 352x640 1 SYRINGES, 133.7ms
# Speed: 3.6ms preprocess, 133.7ms inference, 5.5ms postprocess per image at shape (1, 3, 352, 640)
